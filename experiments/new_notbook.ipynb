# %%
pip install matplotlib numpy pandas seaborn scipy scikit-learn jupyterlab
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: numpy in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (1.15.2)
# Requirement already satisfied: scikit-learn in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (1.6.1)
# Requirement already satisfied: jupyterlab in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (4.4.1)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\likith\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\likith\appdata\roaming\python\python311\site-packages (from jupyterlab) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in c:\users\likith\appdata\roaming\python\python311\site-packages (from jupyterlab) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab) (65.5.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\likith\appdata\roaming\python\python311\site-packages (from jupyterlab) (6.4.2)
# Requirement already satisfied: traitlets in c:\users\likith\appdata\roaming\python\python311\site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (3.7.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\likith\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\likith\appdata\roaming\python\python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: certifi in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipykernel>=6.5.0->jupyterlab) (9.1.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipykernel>=6.5.0->jupyterlab) (7.0.0)
# Requirement already satisfied: colorama in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.4.6)
# Requirement already satisfied: decorator in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\likith\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (4.13.2)
# Requirement already satisfied: wcwidth in c:\users\likith\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\likith\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\likith\appdata\roaming\python\python311\site-packages (from jupyter-core->jupyterlab) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\likith\appdata\roaming\python\python311\site-packages (from jupyter-core->jupyterlab) (310)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.1)
# Requirement already satisfied: six>=1.5 in c:\users\likith\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.4.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.20241206)
# Requirement already satisfied: executing>=1.2.0 in c:\users\likith\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\likith\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\likith\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.3)
# Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 9.4 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/8.1 MB 12.9 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 10.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 7.5 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.1 MB 6.8 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.1 MB 6.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 5.3 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 19.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    ------ --------------------------------- 1/6 [fonttools]
#    -------------------- ------------------- 3/6 [contourpy]
#    -------------------- ------------------- 3/6 [contourpy]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    -------------------------- ------------- 4/6 [matplotlib]
#    --------------------------------- ------ 5/6 [seaborn]
#    --------------------------------- ------ 5/6 [seaborn]
#    --------------------------------- ------ 5/6 [seaborn]
#    --------------------------------- ------ 5/6 [seaborn]
#    --------------------------------- ------ 5/6 [seaborn]
#    --------------------------------- ------ 5/6 [seaborn]
#    --------------------------------- ------ 5/6 [seaborn]
#    ---------------------------------------- 6/6 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=3 in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\likith\appdata\roaming\python\python311\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\likith\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp311-cp311-win_amd64.whl (306 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\likith\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\likith\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(columns = ['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ##Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['target'] = encoder.fit_transform(df['target'])
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df.duplicated().sum()
# Out:
# 403

# %%
len(df)
# Out:
# 5572

# %%
df = df.drop_duplicates(keep = 'first')
len(df)
# Out:
# 5169

# %% [markdown]
# ##Feature Engineering

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\likith\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.stem.porter import PorterStemmer
import string
ps = PorterStemmer()
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    #removing special characters
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    
    #removing stopwords and punctuation
    text = y[:]
    y.clear()

    #loop through tokens and remove stopwords and punction
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    #stemming
    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    
    #returning as a string
    return " ".join(y)

# %%
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\likith\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\likith\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['transformed_text'] = df['text'].apply(transform_text)
df.head()
# Out:
#    target                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tfidf = TfidfVectorizer(max_features=3000)

X = tfidf.fit_transform(df['transformed_text']).toarray()
y = df['target'].values

# %% [markdown]
# ##Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %% [markdown]
# ##Model training

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.1.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\likith\appdata\local\programs\python\python311\lib\site-packages (from xgboost) (1.15.2)
# Downloading xgboost-3.1.3-py3-none-win_amd64.whl (72.0 MB)
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/72.0 MB ? eta -:--:--
#    - -------------------------------------- 2.9/72.0 MB 12.9 MB/s eta 0:00:06
#    -- ------------------------------------- 5.2/72.0 MB 11.0 MB/s eta 0:00:07
#    --- ------------------------------------ 6.0/72.0 MB 9.0 MB/s eta 0:00:08
#    ---- -----------------------------------
0 MB/s eta 0:00:11
#    ----------------------- ---------------- 42.2/72.0 MB 3.0 MB/s eta 0:00:10
#    ------------------------ --------------- 43.5/72.0 MB 3.1 MB/s eta 0:00:10
#    ------------------------ --------------- 44.8/72.0 MB 3.1 MB/s eta 0:00:09
#    ------------------------- -------------- 46.4/72.0 MB 3.2 MB/s eta 0:00:09
#    -------------------------- ------------- 48.0/72.0 MB 3.3 MB/s eta 0:00:08
#    --------------------------- ------------ 49.3/72.0 MB 3.3 MB/s eta 0:00:07
#    --------------------------- ------------ 49.8/72.0 MB 3.3 MB/s eta 0:00:07
#    --------------------------- ------------ 50.3/72.0 MB 3.3 MB/s eta 0:00:07
#    ---------------------------- ----------- 50.9/72.0 MB 3.3 MB/s eta 0:00:07
#    ---------------------------- ----------- 51.6/72.0 MB 3.3 MB/s eta 0:00:07
#    ---------------------------- ----------- 52.2/72.0 MB 3.3 MB/s eta 0:00:07
#    ----------------------------- ---------- 52.7/72.0 MB 3.3 MB/s eta 0:00:06
#    ----------------------------- ---------- 53.5/72.0 MB 3.3 MB/s eta 0:00:06
#    ----------------------------- ---------- 54.0/72.0 MB 3.3 MB/s eta 0:00:06
#    ------------------------------ --------- 54.5/72.0 MB 3.3 MB/s eta 0:00:06
#    ------------------------------ --------- 55.3/72.0 MB 3.2 MB/s eta 0:00:06
#    ------------------------------- -------- 55.8/72.0 MB 3.2 MB/s eta 0:00:05
#    ------------------------------- -------- 56.6/72.0 MB 3.2 MB/s eta 0:00:05
#    ------------------------------- -------- 57.1/72.0 MB 3.2 MB/s eta 0:00:05
#    -------------------------------- ------- 57.9/72.0 MB 3.2 MB/s eta 0:00:05
#    -------------------------------- ------- 58.5/72.0 MB 3.2 MB/s eta 0:00:05
#    -------------------------------- ------- 59.2/72.0 MB 3.2 MB/s eta 0:00:04
#    --------------------------------- ------ 60.0/72.0 MB 3.2 MB/s eta 0:00:04
#    --------------------------------- ------ 60.6/72.0 MB 3.2 MB/s eta 0:00:04
#    ---------------------------------- ----- 61.3/72.0 MB 3.2 MB/s eta 0:00:04
#    ---------------------------------- ----- 62.1/72.0 MB 3.2 MB/s eta 0:00:04
#    ---------------------------------- ----- 62.9/72.0 MB 3.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 63.7/72.0 MB 3.2 MB/s eta 0:00:03
#    ----------------------------------- ---- 64.2/72.0 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------ --- 65.0/72.0 MB 3.3 MB/s eta 0:00:03
#    ------------------------------------ --- 65.8/72.0 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------ --- 66.6/72.0 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------- -- 67.4/72.0 MB 3.3 MB/s eta 0:00:02
#    ------------------------------------- -- 68.2/72.0 MB 3.3 MB/s eta 0:00:02
#    -------------------------------------- - 68.9/72.0 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 69.7/72.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  70.5/72.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  71.3/72.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  71.8/72.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 MB 3.3 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel = 'sigmoid',gamma=1.0)
knc= KNeighborsClassifier()
mnb = MultinomialNB()
lr = LogisticRegression(solver = 'liblinear',penalty ='l1')
dtc = DecisionTreeClassifier(max_depth=5)
rfc = RandomForestClassifier(n_estimators=50,random_state=2)
gbc = GradientBoostingClassifier(n_estimators=50,random_state=2)
abc = AdaBoostClassifier(n_estimators=50,random_state=2)
bgc = BaggingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC': svc,
    'KNeighborsClassifier': knc,
    'MultinomialNB': mnb,
    'LogisticRegression': lr,
    'DecisionTreeClassifier': dtc,
    'RandomForestClassifier': rfc,
    'GradientBoostingClassifier': gbc,
    'AdaBoostClassifier': abc,
    'BaggingClassifier': bgc,
    'XGBClassifier': xgb
}

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import accuracy_score,precision_score
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    return accuracy,precision

# %%
accuracy_scores = []
precision_scores = []
for name,clf in clfs.items():
    current_accuracy,current_precision = train_classifier(clf,X_train,y_train,X_test,y_test)
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    print()
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9758220502901354
# Precision -  0.9747899159663865
#
# For  KNeighborsClassifier
# Accuracy -  0.9052224371373307
# Precision -  1.0
#
# For  MultinomialNB
# Accuracy -  0.9709864603481625
# Precision -  1.0
#
# For  LogisticRegression
# Accuracy -  0.9584139264990329
# Precision -  0.9702970297029703
#
# For  DecisionTreeClassifier
# Accuracy -  0.9294003868471954
# Precision -  0.8282828282828283
#
# For  RandomForestClassifier
# Accuracy -  0.9758220502901354
# Precision -  0.9829059829059829
#
# For  GradientBoostingClassifier
# Accuracy -  0.9468085106382979
# Precision -  0.9191919191919192
#
# For  AdaBoostClassifier
# Accuracy -  0.9245647969052224
# Precision -  0.8488372093023255
#
# For  BaggingClassifier
# Accuracy -  0.9584139264990329
# Precision -  0.8682170542635659
#
# For  XGBClassifier
# Accuracy -  0.9671179883945842
# Precision -  0.9482758620689655
